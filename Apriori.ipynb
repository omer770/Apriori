# %% [markdown]
# # Apriori

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-773fc103-09f3-4f1f-87ba-4da71088f212" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-773fc103-09f3-4f1f-87ba-4da71088f212">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Market_Basket_Optimisation.csv to Market_Basket_Optimisation.csv
# User uploaded file "Market_Basket_Optimisation.csv" with length 302908 bytes

# %%
# Data Preprocessing
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
dataset.shape
# Out:
# (7501, 20)

# %%
dataset
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
transactions = []

# %%
len(dataset)
# Out:
# 7501

# %%
dataset.shape[1]
# Out:
# 20

# %%
for i in range (len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(dataset.shape[1]) if str(dataset.values[i,j])!= 'nan'] )

# %%
transactions[:5]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs']]

# %%
pd.DataFrame(transactions)
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs              None
# 2           chutney               None         None              None
# 3            turkey            avocado         None              None
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread              None
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken               None         None              None
# 7499       escalope          green tea         None              None
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
#training the Apriori on the datasets

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=b800496bff829390ceff32baede0bf79b9714c1c24207c44f57c640d11a6c3db
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
3*7/len(transactions)# minimum support = 0.003 ==> {min 3 products per day }*{7 days per week} /{total transactions a week}
# Out:
# 0.0027996267164378083

# %%
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length =2)

# %%
#Visualising the results

# %%
results = list(rules)

# %%
len(results)
# Out:
# 80

# %%
results[:5]
# Out:
# [RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#                                                 items   support  \
# 0                              (chicken, light cream)  0.004533
# 1                    (escalope, mushroom cream sauce)  0.005733
# 2                                   (pasta, escalope)  0.005866
# 3                              (honey, fromage blanc)  0.003333
# 4                        (ground beef, herb & pepper)  0.015998
# ..                                                ...       ...
# 75  (mineral water, ground beef, olive oil, spaghe...  0.003066
# 76  (mineral water, pancakes, ground beef, spaghetti)  0.003066
# 77  (mineral water, tomatoes, ground beef, spaghetti)  0.003066
# 78        (mineral water, milk, olive oil, spaghetti)  0.003333
# 79         (mineral water, tomatoes, milk, spaghetti)  0.003333
#
#                                    ordered_statistics
# 0   [((light cream), (chicken), 0.2905982905982905...
# 1   [((mushroom cream sauce), (escalope), 0.300699...
# ...

# %%
df.head(5)
# Out:
#                               items   support  \
# 0            (chicken, light cream)  0.004533
# 1  (escalope, mushroom cream sauce)  0.005733
# 2                 (pasta, escalope)  0.005866
# 3            (honey, fromage blanc)  0.003333
# 4      (ground beef, herb & pepper)  0.015998
#
#                                   ordered_statistics
# 0  [((light cream), (chicken), 0.2905982905982905...
# 1  [((mushroom cream sauce), (escalope), 0.300699...
# 2  [((pasta), (escalope), 0.3728813559322034, 4.7...
# 3  [((fromage blanc), (honey), 0.2450980392156863...
# 4  [((herb & pepper), (ground beef), 0.3234501347...

# %%
pd.DataFrame(df.iloc[0,2])
# Out:
#       items_base  items_add  confidence      lift
# 0  (light cream)  (chicken)    0.290598  4.843951

# %%
#2nd row
print(df.iloc[1,:])
pd.DataFrame(df.iloc[1,2])
# Out:
# items                                  (escalope, mushroom cream sauce)
# support                                                        0.005733
# ordered_statistics    [((mushroom cream sauce), (escalope), 0.300699...
# Name: 1, dtype: object
#                items_base   items_add  confidence      lift
# 0  (mushroom cream sauce)  (escalope)    0.300699  3.790833

# %%
df.head()
# Out:
#                               items   support  \
# 0            (chicken, light cream)  0.004533
# 1  (escalope, mushroom cream sauce)  0.005733
# 2                 (pasta, escalope)  0.005866
# 3            (honey, fromage blanc)  0.003333
# 4      (ground beef, herb & pepper)  0.015998
#
#                                   ordered_statistics
# 0  [((light cream), (chicken), 0.2905982905982905...
# 1  [((mushroom cream sauce), (escalope), 0.300699...
# 2  [((pasta), (escalope), 0.3728813559322034, 4.7...
# 3  [((fromage blanc), (honey), 0.2450980392156863...
# 4  [((herb & pepper), (ground beef), 0.3234501347...

# %%
pd.DataFrame(df.ordered_statistics[0])
# Out:
#       items_base  items_add  confidence      lift
# 0  (light cream)  (chicken)    0.290598  4.843951

# %%
b = pd.DataFrame(df.ordered_statistics[0])

# %%
for i in range(1,len(df)):
    b = b.append(pd.DataFrame(df.ordered_statistics[i]))

# %%
b
# Out:
#                                items_base                        items_add  \
# 0                           (light cream)                        (chicken)
# 0                  (mushroom cream sauce)                       (escalope)
# 0                                 (pasta)                       (escalope)
# 0                         (fromage blanc)                          (honey)
# 0                         (herb & pepper)                    (ground beef)
# ..                                    ...                              ...
# 1   (mineral water, milk, nan, spaghetti)                      (olive oil)
# 0                        (tomatoes, milk)  (mineral water, nan, spaghetti)
# 1        (mineral water, milk, spaghetti)                  (tomatoes, nan)
# 2                   (tomatoes, milk, nan)       (mineral water, spaghetti)
# 3   (mineral water, milk, nan, spaghetti)                       (tomatoes)
#
#     confidence      lift
# 0     0.290598  4.843951
# ...

# %%
i = []
z = 0
for num in b.index:
    if num == 0:
        i.append(z)
        z = z+1
    else:
        i.append(z-1)

# %%
b.index = i

# %%
b['support'] = df.support

# %%
b.sort_values(by= ['lift'],ascending=False)
# Out:
#                                             items_base  \
# 150                          (frozen vegetables, soup)
# 97                           (frozen vegetables, soup)
# 150                     (frozen vegetables, nan, soup)
# 96                      (frozen vegetables, olive oil)
# 149                (frozen vegetables, olive oil, nan)
# ..                                                 ...
# 121                         (shrimp, ground beef, nan)
# 49                               (shrimp, ground beef)
# 104       (mineral water, frozen vegetables, tomatoes)
# 153  (mineral water, frozen vegetables, nan, tomatoes)
# 153       (mineral water, frozen vegetables, tomatoes)
#
#                       items_add  confidence      lift   support
# 150  (mineral water, milk, nan)    0.383333  7.987176  0.003066
# 97        (mineral water, milk)    0.383333  7.987176  0.003066
# 150       (mineral water, milk)    0.383333  7.987176  0.003066
# ...

# %%
pd.DataFrame(df.ordered_statistics[0])
# Out:
#       items_base  items_add  confidence      lift
# 0  (light cream)  (chicken)    0.290598  4.843951

# %%
b.columns
# Out:
# Index(['items_base', 'items_add', 'confidence', 'lift', 'support'], dtype='object')

# %%
b = b[['items_base', 'items_add','support', 'confidence',  'lift']]

# %%
b.head()
# Out:
#                items_base      items_add   support  confidence      lift
# 0           (light cream)      (chicken)  0.004533    0.290598  4.843951
# 1  (mushroom cream sauce)     (escalope)  0.005733    0.300699  3.790833
# 2                 (pasta)     (escalope)  0.005866    0.372881  4.700812
# 3         (fromage blanc)        (honey)  0.003333    0.245098  5.164271
# 4         (herb & pepper)  (ground beef)  0.015998    0.323450  3.291994

# %%
b.tail()
# Out:
#                                 items_base                        items_add  \
# 158  (mineral water, milk, nan, spaghetti)                      (olive oil)
# 159                       (tomatoes, milk)  (mineral water, nan, spaghetti)
# 159       (mineral water, milk, spaghetti)                  (tomatoes, nan)
# 159                  (tomatoes, milk, nan)       (mineral water, spaghetti)
# 159  (mineral water, milk, nan, spaghetti)                       (tomatoes)
#
#       support  confidence      lift
# 158  0.003333    0.211864  3.216994
# 159  0.003333    0.238095  3.986501
# 159  0.003333    0.211864  3.097846
# 159  0.003333    0.238095  3.986501
# 159  0.003333    0.211864  3.097846

# %%
#Check Maximum sold item

# %%
rvl = dataset.values.ravel()

# %%
import collections

# %%
val = collections.Counter(rvl)
pd.DataFrame(val.items())
# Out:
#                   0    1
# 0            shrimp  536
# 1           almonds  153
# 2           avocado  250
# 3    vegetables mix  193
# 4      green grapes   68
# ..              ...  ...
# 116    burger sauce   44
# 117         oatmeal   33
# 118       asparagus    1
# 119           cream    7
# 120         napkins    5
#
# [121 rows x 2 columns]

# %%
df = pd.DataFrame(val.items(), columns = ['items', 'Count'])
df.head(10)
# Out:
#               items  Count
# 0            shrimp    536
# 1           almonds    153
# 2           avocado    250
# 3    vegetables mix    193
# 4      green grapes     68
# 5  whole weat flour     70
# 6              yams     86
# 7    cottage cheese    239
# 8      energy drink    200
# 9      tomato juice    228

# %%
df.sort_values(by= 'Count', ascending = False)[1:]
# Out:
#              items  Count
# 14   mineral water   1788
# 22            eggs   1348
# 35       spaghetti   1306
# 30    french fries   1282
# 40       chocolate   1230
# ..             ...    ...
# 115        bramble     14
# 119          cream      7
# 120        napkins      5
# 98     water spray      3
# 118      asparagus      1
#
# [120 rows x 2 columns]

# %%
df2 = df.sort_values(by= 'Count', ascending = False)[1:]

# %%
df2['Support'] = df2['Count']/float(len(df2))

# %%
df2.head(20)
# Out:
#                 items  Count     Supprt
# 14      mineral water   1788  14.900000
# 22               eggs   1348  11.233333
# 35          spaghetti   1306  10.883333
# 30       french fries   1282  10.683333
# 40          chocolate   1230  10.250000
# 11          green tea    991   8.258333
# 26               milk    972   8.100000
# 62        ground beef    737   6.141667
# 34  frozen vegetables    715   5.958333
# 56           pancakes    713   5.941667
# 20            burgers    654   5.450000
# 70               cake    608   5.066667
# 37            cookies    603   5.025000
# 63           escalope    595   4.958333
# 10     low fat yogurt    574   4.783333
# 0              shrimp    536   4.466667
# 44           tomatoes    513   4.275000
# 19          olive oil    494   4.116667
# 17    frozen smoothie    475   3.958333
# 25             turkey    469   3.908333
